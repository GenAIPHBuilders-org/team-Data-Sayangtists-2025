# %% [markdown]
# ## Testing Gemini API

# %%
import google.generativeai as genai
from dotenv import load_dotenv
from collections import defaultdict
import os, json, requests

# Load environment variables from .env file
load_dotenv(dotenv_path="../env/.env")

# First configure your API key
genai.configure(api_key=os.getenv("GOOG_API_KEY"))

# List models
models = genai.list_models()

# Print model names
for model in models:
    print(model.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.5-flash-preview-04-17-thinking
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/aqa
# models/imagen-3.0-generate-002
# models/gemini-2.0-flash-live-001

# %%
# Configure API key
genai.configure(api_key=os.getenv("GOOG_API_KEY"))

# Initialize model
model = genai.GenerativeModel("models/gemini-2.0-flash")

# Text prompt
prompt = """You are a helpful assistant that summarizes content themes concisely.
Given the following text, identify and return a maximum of three one-word themes that best represent the main idea. 
Respond with only the one-word themes, separated by commas. No explanation or extra text.

Text: Wow, today was actually pretty amazing. Got a ton done on the side project, which feels great, but honestly, the best part was working with him.

He’s not just insanely good-looking (like, seriously, how is someone that handsome?), but also really smart and chill. Sitting next to him, bouncing ideas back and forth, it felt... different. I kept catching myself smiling more than usual.

There were those little moments—like when our hands accidentally touched or when he laughed at something dumb I said—and my heart definitely did a little jump. I don’t think I was imagining it.

I’m not sure if he feels the same vibe, but just being around him makes the whole day better. Can’t wait to see what comes next, but for now, I’m just glad I got to spend time with him and actually get stuff done.

This might be the start of something cool.

Themes:"""

# Generate response
try:
    response = model.generate_content(prompt)
    print(response.text.strip())
except Exception as e:
    print(f"Error: {e}")
# Out:
# Attraction, Infatuation, Project

# %%
themes = response.text.strip().lower().replace(".", "").split(",")
themes = [t.strip() for t in themes if t.strip()]

# %% [markdown]
# ## Integrating into LastFM

# %% [markdown]
# The themes work when words are copy-pasted simply. I'll just find a way to make it work. Continuing it tomorrow.

# %%
# The themes

lfm_api = os.getenv("LFM_API_KEY")

def get_top_tracks_by_theme(theme):
    url = "https://ws.audioscrobbler.com/2.0/"
    params = {
        "method": "tag.gettoptracks",
        "tag": theme,
        "api_key": lfm_api,
        "format": "json",
        "limit": 10  # Optional: limit to top 10 for brevity
    }
    response = requests.get(url, params=params)
    return response.json()

results = defaultdict(list)

for theme in themes:
    print(f"Fetching tracks for theme: {theme}")
    data = get_top_tracks_by_theme(theme)
    tracks = data.get("tracks", {}).get("track", [])
    results[theme] = tracks
# Out:
# Fetching tracks for theme: attraction
# Fetching tracks for theme: infatuation
# Fetching tracks for theme: project

# %%
print(json.dumps(results, indent=2))
# Out:
# {
#   "attraction": [
#     {
#       "name": "Super Crush",
#       "duration": "132",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Tiger+Trap/_/Super+Crush",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Tiger Trap",
#         "mbid": "7903b54d-b1ce-4061-91ef-4e8b25fbdc33",
#         "url": "https://www.last.fm/music/Tiger+Trap"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "1"
#       }
#     },
#     {
#       "name": "The Little Girl I Once Knew",
#       "duration": "158",
#       "mbid": "d1e2bf36-20a1-44b6-baf1-52441aeb841c",
#       "url": "https://www.last.fm/music/The+Beach+Boys/_/The+Little+Girl+I+Once+Knew",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "The Beach Boys",
#         "mbid": "ebfc1398-8d96-47e3-82c3-f782abcdb13d",
#         "url": "https://www.last.fm/music/The+Beach+Boys"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "2"
#       }
#     },
#     {
#       "name": "Your Way",
#       "duration": "243",
#       "mbid": "68b61d99-ba4e-44e4-89a0-43101cc6a49f",
#       "url": "https://www.last.fm/music/Sarah+Blasko/_/Your+Way",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Sarah Blasko",
#         "mbid": "fa319aa2-15cb-4d02-8a0b-7080869e43ca",
#         "url": "https://www.last.fm/music/Sarah+Blasko"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "3"
#       }
#     },
#     {
#       "name": "Power of Attraction",
#       "duration": "254",
#       "mbid": "1e849018-87e2-4935-be0a-50a8d05e3fb0",
#       "url": "https://www.last.fm/music/Natalia+Lesz/_/Power+of+Attraction",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Natalia Lesz",
#         "mbid": "43899142-1cd4-451f-830c-24ff7d49d207",
#         "url": "https://www.last.fm/music/Natalia+Lesz"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "4"
#       }
#     },
#     {
#       "name": "Baby You've Been On My Mind",
#       "duration": "177",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Dylan+Singh/_/Baby+You%27ve+Been+On+My+Mind",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Dylan Singh",
#         "mbid": "",
#         "url": "https://www.last.fm/music/Dylan+Singh"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "5"
#       }
#     },
#     {
#       "name": "You Look So Good",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Clare+Bowditch/_/You+Look+So+Good",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Clare Bowditch",
#         "mbid": "0e60751f-17df-4c56-8f51-b71f7bae4f19",
#         "url": "https://www.last.fm/music/Clare+Bowditch"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "6"
#       }
#     },
#     {
#       "name": "Attraction (Edit Version)",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Antoine+Clamaran/_/Attraction+(Edit+Version)",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Antoine Clamaran",
#         "mbid": "97e22c69-536b-4365-9934-13426a5da923",
#         "url": "https://www.last.fm/music/Antoine+Clamaran"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "7"
#       }
#     },
#     {
#       "name": "\u56db\u5b63",
#       "duration": "255",
#       "mbid": "c49a8888-dd9a-4fe0-bc11-ab239749be4b",
#       "url": "https://www.last.fm/music/%E5%A4%A7%E8%B2%AB%E5%A6%99%E5%AD%90/_/%E5%9B%9B%E5%AD%A3",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "\u5927\u8cab\u5999\u5b50",
#         "mbid": "8370abe0-dbe1-48f4-99d5-6646ff2d8264",
#         "url": "https://www.last.fm/music/%E5%A4%A7%E8%B2%AB%E5%A6%99%E5%AD%90"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "8"
#       }
#     },
#     {
#       "name": "Cicada",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/%E5%A4%A7%E8%B2%AB%E5%A6%99%E5%AD%90/_/Cicada",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "\u5927\u8cab\u5999\u5b50",
#         "mbid": "8370abe0-dbe1-48f4-99d5-6646ff2d8264",
#         "url": "https://www.last.fm/music/%E5%A4%A7%E8%B2%AB%E5%A6%99%E5%AD%90"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "9"
#       }
#     },
#     {
#       "name": "Von Der Dunkelheit Und Ihrer Anziehungskraft",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/GWLT/_/Von+Der+Dunkelheit+Und+Ihrer+Anziehungskraft",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "GWLT",
#         "mbid": "f0750eb0-fc9f-4efa-a9d8-90631e48da81",
#         "url": "https://www.last.fm/music/GWLT"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "10"
#       }
#     }
#   ],
#   "infatuation": [
#     {
#       "name": "Sofia",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Clairo/_/Sofia",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Clairo",
#         "mbid": "",
#         "url": "https://www.last.fm/music/Clairo"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "1"
#       }
#     },
#     {
#       "name": "Streets",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Doja+Cat/_/Streets",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Doja Cat",
#         "mbid": "5df62a88-cac9-490a-b62c-c7c88f4020f4",
#         "url": "https://www.last.fm/music/Doja+Cat"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "2"
#       }
#     },
#     {
#       "name": "Levitating (feat. DaBaby)",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Dua+Lipa/_/Levitating+(feat.+DaBaby)",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Dua Lipa",
#         "mbid": "",
#         "url": "https://www.last.fm/music/Dua+Lipa"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "3"
#       }
#     },
#     {
#       "name": "Boyfriend (with Social House)",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Ariana+Grande/_/Boyfriend+(with+Social+House)",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Ariana Grande",
#         "mbid": "f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387",
#         "url": "https://www.last.fm/music/Ariana+Grande"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "4"
#       }
#     },
#     {
#       "name": "Prisoner (feat. Dua Lipa)",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Miley+Cyrus/_/Prisoner+(feat.+Dua+Lipa)",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Miley Cyrus",
#         "mbid": "7e9bd05a-117f-4cce-87bc-e011527a8b18",
#         "url": "https://www.last.fm/music/Miley+Cyrus"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "5"
#       }
#     },
#     {
#       "name": "Falling for U",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Peachy%21/_/Falling+for+U",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Peachy!",
#         "mbid": "",
#         "url": "https://www.last.fm/music/Peachy%21"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "6"
#       }
#     },
#     {
#       "name": "Fearless (Taylor\u2019s Version)",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Taylor+Swift/_/Fearless+(Taylor%E2%80%99s+Version)",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Taylor Swift",
#         "mbid": "20244d07-534f-4eff-b4d4-930878889970",
#         "url": "https://www.last.fm/music/Taylor+Swift"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "7"
#       }
#     },
#     {
#       "name": "Sweetener",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Ariana+Grande/_/Sweetener",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Ariana Grande",
#         "mbid": "f4fdbb4c-e4b7-47a0-b83b-d91bbfcfa387",
#         "url": "https://www.last.fm/music/Ariana+Grande"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "8"
#       }
#     },
#     {
#       "name": "The Weekend - Funk Wav Remix",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/SZA/_/The+Weekend+-+Funk+Wav+Remix",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "SZA",
#         "mbid": "272989c8-5535-492d-a25c-9f58803e027f",
#         "url": "https://www.last.fm/music/SZA"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "9"
#       }
#     },
#     {
#       "name": "Someone To You",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Banners/_/Someone+To+You",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Banners",
#         "mbid": "",
#         "url": "https://www.last.fm/music/Banners"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "10"
#       }
#     }
#   ],
#   "project": [
#     {
#       "name": "The Hazards of Love 2 (Wager All)",
#       "duration": "265",
#       "mbid": "50c834d0-b2e5-4562-adb7-238da4bab65d",
#       "url": "https://www.last.fm/music/The+Decemberists/_/The+Hazards+of+Love+2+(Wager+All)",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "The Decemberists",
#         "mbid": "97b1142f-c71e-4971-8736-4a8ceaf6b4c3",
#         "url": "https://www.last.fm/music/The+Decemberists"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "1"
#       }
#     },
#     {
#       "name": "Margaret in Captivity",
#       "duration": "187",
#       "mbid": "898b1471-0729-4ba9-bf32-4610b78be6d0",
#       "url": "https://www.last.fm/music/The+Decemberists/_/Margaret+in+Captivity",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "The Decemberists",
#         "mbid": "97b1142f-c71e-4971-8736-4a8ceaf6b4c3",
#         "url": "https://www.last.fm/music/The+Decemberists"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "2"
#       }
#     },
#     {
#       "name": "Woke Up New",
#       "duration": "177",
#       "mbid": "547bd584-0fb2-4fc0-8da8-108291e7746c",
#       "url": "https://www.last.fm/music/The+Mountain+Goats/_/Woke+Up+New",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "The Mountain Goats",
#         "mbid": "9639cd52-c351-4a17-9797-58880e95a7ef",
#         "url": "https://www.last.fm/music/The+Mountain+Goats"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "3"
#       }
#     },
#     {
#       "name": "The Hazards of Love 3 (Revenge!)",
#       "duration": "202",
#       "mbid": "3a705a47-cc69-4aa5-ab63-e8bf26bb5432",
#       "url": "https://www.last.fm/music/The+Decemberists/_/The+Hazards+of+Love+3+(Revenge%21)",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "The Decemberists",
#         "mbid": "97b1142f-c71e-4971-8736-4a8ceaf6b4c3",
#         "url": "https://www.last.fm/music/The+Decemberists"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "4"
#       }
#     },
#     {
#       "name": "It's Okay",
#       "duration": "294",
#       "mbid": "2f9a1262-a192-43e0-a488-c64e62eb6985",
#       "url": "https://www.last.fm/music/Land+of+Talk/_/It%27s+Okay",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Land of Talk",
#         "mbid": "336dfcad-2587-4f5d-9338-3a445282364f",
#         "url": "https://www.last.fm/music/Land+of+Talk"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "5"
#       }
#     },
#     {
#       "name": "Minotaur",
#       "duration": "290",
#       "mbid": "bb673f8d-1787-4ec5-9d34-6b1c2ad6aa45",
#       "url": "https://www.last.fm/music/Thee+Oh+Sees/_/Minotaur",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Thee Oh Sees",
#         "mbid": "194272cc-dcc8-4640-a4a6-66da7d250d5c",
#         "url": "https://www.last.fm/music/Thee+Oh+Sees"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "6"
#       }
#     },
#     {
#       "name": "Tonite It Shows",
#       "duration": "220",
#       "mbid": "1523e0c4-3cb6-470b-9bd3-21ef45da02e6",
#       "url": "https://www.last.fm/music/Mercury+Rev/_/Tonite+It+Shows",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Mercury Rev",
#         "mbid": "7b1cf87e-c54f-4abc-893d-90245a31900d",
#         "url": "https://www.last.fm/music/Mercury+Rev"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "7"
#       }
#     },
#     {
#       "name": "Now I Know You Could Never Be the One",
#       "duration": "242",
#       "mbid": "7989902e-38d3-45b3-97c3-e53503fb90ac",
#       "url": "https://www.last.fm/music/The+Meeting+Places/_/Now+I+Know+You+Could+Never+Be+the+One",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "The Meeting Places",
#         "mbid": "fe2ca5c7-099c-4482-8eb9-03e9592458be",
#         "url": "https://www.last.fm/music/The+Meeting+Places"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "8"
#       }
#     },
#     {
#       "name": "Chaos Engine",
#       "duration": "218",
#       "mbid": "c4cdab86-bd6b-4d03-8f19-f7fb31d9406f",
#       "url": "https://www.last.fm/music/Pinback/_/Chaos+Engine",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Pinback",
#         "mbid": "1f16a425-2606-4137-a6b7-234b6dabe037",
#         "url": "https://www.last.fm/music/Pinback"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "9"
#       }
#     },
#     {
#       "name": "Rousseau",
#       "duration": "0",
#       "mbid": "5eb84356-63b2-43f2-9865-013bb6a0fbc8",
#       "url": "https://www.last.fm/music/Pinback/_/Rousseau",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Pinback",
#         "mbid": "1f16a425-2606-4137-a6b7-234b6dabe037",
#         "url": "https://www.last.fm/music/Pinback"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "10"
#       }
#     }
#   ]
# }
