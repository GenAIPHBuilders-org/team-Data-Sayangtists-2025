# %% [markdown]
# ## Testing Gemini API (Gemma)

# %%
import google.generativeai as genai
from dotenv import load_dotenv
from collections import defaultdict
import os, json, requests

# Load environment variables from .env file
load_dotenv(dotenv_path="../../env/.env")

# First configure your API key
genai.configure(api_key=os.getenv("GOOG_API_KEY"))

# List models
models = genai.list_models()

# Print model names
for model in models:
    print(model.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.5-flash-preview-04-17-thinking
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/aqa
# models/imagen-3.0-generate-002
# models/gemini-2.0-flash-live-001

# %%
# Configure API key
genai.configure(api_key=os.getenv("GOOG_API_KEY"))

# Initialize model
model = genai.GenerativeModel("models/gemini-2.0-flash")

# Text prompt
prompt = """You are a helpful assistant that summarizes content themes concisely.
Given the following text, identify and return a maximum of three one-word themes that best represent the main idea. 
Respond with only the one-word themes, separated by commas. No explanation or extra text.

Text: It has been three days since we ended things, and the silence feels louder than any of the arguments we had. I keep catching myself reaching for my phone to send you something — a meme, a random thought, a picture of the dog on my street that always made you laugh. Then I remember: we are not we anymore. It is just me, retraining my reflexes to live without you. What hurts most isn’t the loss of the relationship itself, but the quiet disappearance of the future I had imagined. The vacations we talked about, the dumb traditions we started, the way you made tea too strong — it’s all gone, like a movie that got cancelled mid-season. I’m not angry. Not really. I’m just... hollow. Like I’ve misplaced something vital, and I won’t even know how to look for it yet. But I’m still writing. Still breathing. Still here. And that has to count for something.

Themes:"""

# Generate response
try:
    response = model.generate_content(prompt)
    print(response.text.strip())
except Exception as e:
    print(f"Error: {e}")
# Out:
# Loss, Grief, Absence

# %%
themes = response.text.strip().lower().replace(".", "").split(",")
themes = [t.strip() for t in themes if t.strip()]

# %% [markdown]
# ## Integrating into LastFM

# %% [markdown]
# The themes work when words are copy-pasted simply. I'll just find a way to make it work. Continuing it tomorrow.

# %%
# The themes

lfm_api = os.getenv("LFM_API_KEY")

def get_top_tracks_by_theme(theme):
    url = "https://ws.audioscrobbler.com/2.0/"
    params = {
        "method": "tag.gettoptracks",
        "tag": theme,
        "api_key": lfm_api,
        "format": "json",
        "limit": 10  # Optional: limit to top 10 for brevity
    }
    response = requests.get(url, params=params)
    return response.json()

results = defaultdict(list)

for theme in themes:
    print(f"Fetching tracks for theme: {theme}")
    data = get_top_tracks_by_theme(theme)
    tracks = data.get("tracks", {}).get("track", [])
    results[theme] = tracks
# Out:
# Fetching tracks for theme: loss
# Fetching tracks for theme: grief
# Fetching tracks for theme: absence

# %%
print(json.dumps(results, indent=2))
# Out:
# {
#   "loss": [
#     {
#       "name": "CORALINE",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/M%C3%A5neskin/_/CORALINE",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "M\u00e5neskin",
#         "mbid": "",
#         "url": "https://www.last.fm/music/M%C3%A5neskin"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "1"
#       }
#     },
#     {
#       "name": "My Mummy's Dead",
#       "duration": "49",
#       "mbid": "6020e5fe-8b16-46c7-a740-b2f9744bc3b4",
#       "url": "https://www.last.fm/music/John+Lennon/_/My+Mummy%27s+Dead",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "John Lennon",
#         "mbid": "4d5447d7-c61c-4120-ba1b-d7f471d385b9",
#         "url": "https://www.last.fm/music/John+Lennon"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "2"
#       }
#     },
#     {
#       "name": "Gone",
#       "duration": "202",
#       "mbid": "fac4ad46-7c8d-4af1-9aac-cae3ce93efc1",
#       "url": "https://www.last.fm/music/Ben+Folds/_/Gone",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Ben Folds",
#         "mbid": "51b7f46f-6c0f-46f2-9496-08c9ec2624d4",
#         "url": "https://www.last.fm/music/Ben+Folds"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "3"
#       }
#     },
#     {
#       "name": "And All That Could Have Been",
#       "duration": "374",
#       "mbid": "f48f3b65-7864-4932-94b0-f4a1900a4512",
#       "url": "https://www.last.fm/music/Nine+Inch+Nails/_/And+All+That+Could+Have+Been",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Nine Inch Nails",
#         "mbid": "b7ffd2af-418f-4be2-bdd1-22f8b48613da",
#         "url": "https://www.last.fm/music/Nine+Inch+Nails"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "4"
#       }
#     },
#     {
#       "name": "Moon sequel",
#       "duration": "249",
#       "mbid": "149216c1-5ca6-4bbb-8a53-e9d13d5f0791",
#       "url": "https://www.last.fm/music/Mount+Eerie/_/Moon+sequel",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Mount Eerie",
#         "mbid": "e5306b29-16c0-4520-bb05-6b21f041b2f0",
#         "url": "https://www.last.fm/music/Mount+Eerie"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "5"
#       }
#     },
#     {
#       "name": "Laura",
#       "duration": "255",
#       "mbid": "9279d934-923c-4692-bcfa-8611821f0060",
#       "url": "https://www.last.fm/music/Flogging+Molly/_/Laura",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Flogging Molly",
#         "mbid": "c3694ddc-f7e5-40dd-9fad-90d11a2c50fa",
#         "url": "https://www.last.fm/music/Flogging+Molly"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "6"
#       }
#     },
#     {
#       "name": "The Persistence of Loss",
#       "duration": "243",
#       "mbid": "1396ae7b-858c-4f5b-beb1-54406f57109d",
#       "url": "https://www.last.fm/music/Nine+Inch+Nails/_/The+Persistence+of+Loss",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Nine Inch Nails",
#         "mbid": "b7ffd2af-418f-4be2-bdd1-22f8b48613da",
#         "url": "https://www.last.fm/music/Nine+Inch+Nails"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "7"
#       }
#     },
#     {
#       "name": "La Vie a 2",
#       "duration": "180",
#       "mbid": "c0eb7b94-0a4d-4e1f-b4c5-6633acc8cbfd",
#       "url": "https://www.last.fm/music/Manu+Chao/_/La+Vie+a+2",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Manu Chao",
#         "mbid": "7570a0dd-5a67-401b-b19a-261eee01a284",
#         "url": "https://www.last.fm/music/Manu+Chao"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "8"
#       }
#     },
#     {
#       "name": "5:15 the Angels Have Gone",
#       "duration": "300",
#       "mbid": "3137926b-e099-4d17-bdee-c92a6b4a39e1",
#       "url": "https://www.last.fm/music/David+Bowie/_/5:15+the+Angels+Have+Gone",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "David Bowie",
#         "mbid": "5441c29d-3602-4898-b1a1-b77fa23b8e50",
#         "url": "https://www.last.fm/music/David+Bowie"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "9"
#       }
#     },
#     {
#       "name": "Things",
#       "duration": "0",
#       "mbid": "fcc753cc-e38c-450e-a2a3-faefa97ab4b5",
#       "url": "https://www.last.fm/music/Frightened+Rabbit/_/Things",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Frightened Rabbit",
#         "mbid": "dc21d171-7204-4759-9fd0-77d031aeb40c",
#         "url": "https://www.last.fm/music/Frightened+Rabbit"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "10"
#       }
#     }
#   ],
#   "grief": [
#     {
#       "name": "Nikes",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Frank+Ocean/_/Nikes",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Frank Ocean",
#         "mbid": "e520459c-dff4-491d-a6e4-c97be35e0044",
#         "url": "https://www.last.fm/music/Frank+Ocean"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "1"
#       }
#     },
#     {
#       "name": "Sing About Me, I'm Dying of Thirst",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Kendrick+Lamar/_/Sing+About+Me,+I%27m+Dying+of+Thirst",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Kendrick Lamar",
#         "mbid": "381086ea-f511-4aba-bdf9-71c753dc5077",
#         "url": "https://www.last.fm/music/Kendrick+Lamar"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "2"
#       }
#     },
#     {
#       "name": "Bad News",
#       "duration": "239",
#       "mbid": "1818fc80-7c01-4dda-89e1-a24851ad1838",
#       "url": "https://www.last.fm/music/Kanye+West/_/Bad+News",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Kanye West",
#         "mbid": "164f0d73-1234-4e2c-8743-d77bf2191051",
#         "url": "https://www.last.fm/music/Kanye+West"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "3"
#       }
#     },
#     {
#       "name": "Ronan (Taylor's Version)",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Taylor+Swift/_/Ronan+(Taylor%27s+Version)",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Taylor Swift",
#         "mbid": "20244d07-534f-4eff-b4d4-930878889970",
#         "url": "https://www.last.fm/music/Taylor+Swift"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "4"
#       }
#     },
#     {
#       "name": "Lone",
#       "duration": "237",
#       "mbid": "709e360c-4053-4dad-a02c-a7314ffee8eb",
#       "url": "https://www.last.fm/music/Tyler,+the+Creator/_/Lone",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Tyler, the Creator",
#         "mbid": "f6beac20-5dfe-4d1f-ae02-0b0a740aafd6",
#         "url": "https://www.last.fm/music/Tyler,+the+Creator"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "5"
#       }
#     },
#     {
#       "name": "I Get Along Without You Very Well (Except Sometimes) - Vocal Version",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Chet+Baker/_/I+Get+Along+Without+You+Very+Well+(Except+Sometimes)+-+Vocal+Version",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Chet Baker",
#         "mbid": "1ba1d493-7114-45e2-b163-a36d49a0c065",
#         "url": "https://www.last.fm/music/Chet+Baker"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "6"
#       }
#     },
#     {
#       "name": "Real Death",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Mount+Eerie/_/Real+Death",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Mount Eerie",
#         "mbid": "e5306b29-16c0-4520-bb05-6b21f041b2f0",
#         "url": "https://www.last.fm/music/Mount+Eerie"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "7"
#       }
#     },
#     {
#       "name": "Grief",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Earl+Sweatshirt/_/Grief",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Earl Sweatshirt",
#         "mbid": "8b22acd6-20e6-4463-a75c-c14b5cfdb666",
#         "url": "https://www.last.fm/music/Earl+Sweatshirt"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "8"
#       }
#     },
#     {
#       "name": "Playing Possum (feat. Cheryl Harris & Keorapetse Kgositsile)",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Earl+Sweatshirt/_/Playing+Possum+(feat.+Cheryl+Harris+&+Keorapetse+Kgositsile)",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Earl Sweatshirt",
#         "mbid": "8b22acd6-20e6-4463-a75c-c14b5cfdb666",
#         "url": "https://www.last.fm/music/Earl+Sweatshirt"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "9"
#       }
#     },
#     {
#       "name": "Two of Us",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Louis+Tomlinson/_/Two+of+Us",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Louis Tomlinson",
#         "mbid": "",
#         "url": "https://www.last.fm/music/Louis+Tomlinson"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "10"
#       }
#     }
#   ],
#   "absence": [
#     {
#       "name": "No Step On Wing",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/Nils+Frahm/_/No+Step+On+Wing",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Nils Frahm",
#         "mbid": "d03a54bc-6e07-4c04-a8d4-7fbf2bd07a01",
#         "url": "https://www.last.fm/music/Nils+Frahm"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "1"
#       }
#     },
#     {
#       "name": "This Twilight Garden",
#       "duration": "285",
#       "mbid": "9b7a9d1c-127a-4f21-b4eb-db95bf03b00d",
#       "url": "https://www.last.fm/music/The+Cure/_/This+Twilight+Garden",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "The Cure",
#         "mbid": "69ee3720-a7cb-4402-b48d-a02c366f2bcf",
#         "url": "https://www.last.fm/music/The+Cure"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "2"
#       }
#     },
#     {
#       "name": "Okkervil River Song",
#       "duration": "0",
#       "mbid": "6660141a-9c08-4cf4-a670-570cafe8ebf5",
#       "url": "https://www.last.fm/music/Okkervil+River/_/Okkervil+River+Song",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Okkervil River",
#         "mbid": "9fa07bb4-8312-4cd7-a19a-4fdbc5797148",
#         "url": "https://www.last.fm/music/Okkervil+River"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "3"
#       }
#     },
#     {
#       "name": "Als Ze Er Niet Is",
#       "duration": "210",
#       "mbid": "dc83eefc-c72f-4104-9534-a20cdaf4b95a",
#       "url": "https://www.last.fm/music/De+Dijk/_/Als+Ze+Er+Niet+Is",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "De Dijk",
#         "mbid": "d7a55e92-a14c-4543-8152-de2163af06bb",
#         "url": "https://www.last.fm/music/De+Dijk"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "4"
#       }
#     },
#     {
#       "name": "I Get Along Without You Very Well",
#       "duration": "293",
#       "mbid": "33c3a1e8-9efd-4558-8f1e-82cd261be428",
#       "url": "https://www.last.fm/music/Nina+Simone/_/I+Get+Along+Without+You+Very+Well",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Nina Simone",
#         "mbid": "2944824d-4c26-476f-a981-be849081942f",
#         "url": "https://www.last.fm/music/Nina+Simone"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "5"
#       }
#     },
#     {
#       "name": "Time Without You",
#       "duration": "171",
#       "mbid": "c62f0566-cb94-4e94-b807-0ae517b30244",
#       "url": "https://www.last.fm/music/Dale+Watson/_/Time+Without+You",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Dale Watson",
#         "mbid": "57c04acd-8552-479b-b987-aa0eb7d807cb",
#         "url": "https://www.last.fm/music/Dale+Watson"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "6"
#       }
#     },
#     {
#       "name": "My World Is Empty Without You",
#       "duration": "190",
#       "mbid": "157ed285-0d1c-4f00-a3d7-f5afe557b750",
#       "url": "https://www.last.fm/music/Barbara+McNair/_/My+World+Is+Empty+Without+You",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Barbara McNair",
#         "mbid": "473a046f-57db-43d3-accb-d16167c6efe8",
#         "url": "https://www.last.fm/music/Barbara+McNair"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "7"
#       }
#     },
#     {
#       "name": "Absence Of Your Kiss",
#       "duration": "0",
#       "mbid": "",
#       "url": "https://www.last.fm/music/K-Precise/_/Absence+Of+Your+Kiss",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "K-Precise",
#         "mbid": "",
#         "url": "https://www.last.fm/music/K-Precise"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "8"
#       }
#     },
#     {
#       "name": "When You're Gone",
#       "duration": "301",
#       "mbid": "e4c8e247-ef7a-486d-bc45-efe3273c29d1",
#       "url": "https://www.last.fm/music/The+Delfonics/_/When+You%27re+Gone",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "The Delfonics",
#         "mbid": "cfe0dee4-4409-46e3-bbf2-edac88971132",
#         "url": "https://www.last.fm/music/The+Delfonics"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "9"
#       }
#     },
#     {
#       "name": "My World is Empty Without You",
#       "duration": "201",
#       "mbid": "29c4916e-cbd0-4c0a-8408-8ff0961871bc",
#       "url": "https://www.last.fm/music/Mary+McCaslin/_/My+World+is+Empty+Without+You",
#       "streamable": {
#         "#text": "0",
#         "fulltrack": "0"
#       },
#       "artist": {
#         "name": "Mary McCaslin",
#         "mbid": "dfc27868-6f62-40a3-a0b5-ee92b196d5f9",
#         "url": "https://www.last.fm/music/Mary+McCaslin"
#       },
#       "image": [
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "small"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "medium"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "large"
#         },
#         {
#           "#text": "https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png",
#           "size": "extralarge"
#         }
#       ],
#       "@attr": {
#         "rank": "10"
#       }
#     }
#   ]
# }

# %%
import google.generativeai as genai
import dotenv
import requests

# These are from the standard library; no version printing needed
#import os
#import json
#import collections

print(f"google-generativeai=={genai.__version__}")
print(f"requests=={requests.__version__}")
# python-dotenv does not provide __version__ attribute directly
try:
	import importlib.metadata
	print(f"python-dotenv=={importlib.metadata.version('python-dotenv')}")
except Exception as e:
	print("Could not determine python-dotenv version:", e)
# Out:
# google-generativeai==0.8.5
# requests==2.32.3
# python-dotenv==1.1.0
